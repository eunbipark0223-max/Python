# %% [markdown]
# # 📘 파이썬 기초: 01. 프로그래밍과 파이썬

# %% [markdown]
# #h1
# ##h2
# ###h3

# %% [markdown]
# ## 1. 프로그래밍 언어
# * **프로그래밍의 이해**:
#     * **프로그램(Program)**: 컴퓨터로 문제를 해결하기 위해 작성하는 명령어의 모음입니다.
#     * **프로그래밍(Programming)**: 프로그램을 작성하는 과정입니다.
#     * **프로그래머(Programmer)**: 프로그램을 작성하는 사람을 말합니다.
# * **프로그래밍 언어의 종류**:
#     * **저급 언어**: 기계 중심의 언어로 하드웨어 지향적입니다. (예: 어셈블리어)
#     * **고급 언어**: 사람이 이해하기 쉬운 언어와 기호를 사용합니다. (예: C, 자바, 파이썬 등)
# * **언어 번역**: 사람이 작성한 고급 언어를 컴퓨터가 이해할 수 있는 기계어로 변환하는 과정이 필요합니다.

# %%
print('안녕하세요!')

# %% [markdown]
# ## 2. 파이썬의 개념
# * **파이썬(Python)**: 1991년 귀도 반 로섬이 발표한 프로그래밍 언어입니다.
# * **주요 특징**:
#     * 문법이 간결하고 사람의 언어와 비슷하여 배우기 쉽습니다.
#     * 다양한 분야(데이터 분석, 인공지능, 웹 개발 등)에서 활용할 수 있는 풍부한 라이브러리를 제공합니다.
#     * 무료로 사용할 수 있는 오픈 소스입니다.

# %% [markdown]
# # 파이썬의 특징
#
#
# *   인기있는 이유: 다양한 라이브러리 활용 가능
# *   라이브러리: NumPy(고성능 수치계산),사이킷런(분류,회기,군집화)
#
# #파이썬 변수 이름 규칙
# * 첫번째 글자는 문자 또는 밑줄로 시작해야함(숫자가 먼저 올 수 없음)
# * 영문자 대소문 구분
# * 예약어를 변수로 쓸 수 없음

# %% [markdown]
# ## 3. 파이썬 개발 환경
# * **구글 코랩(Google Colab)**: 웹 브라우저에서 파이썬 코드를 작성하고 실행할 수 있는 서비스입니다.
#     * 별도의 설치 없이 무료로 사용할 수 있습니다.
#     * 작성한 파일은 구글 드라이브(`Colab Notebooks` 폴더)에 자동으로 저장됩니다.
# * **구성 요소**:
#     * **코드 셀**: 파이썬 코드를 입력하고 실행하는 공간입니다.
#     * **텍스트 셀**: 설명이나 메모를 마크다운 형식으로 작성하는 공간입니다.

# %% [markdown]
# ## 4. 처음 만나는 프로그램
# * **프로그램 실행**: 코드 셀에 소스 코드를 입력한 후 실행 버튼을 누르거나 단축키(`Ctrl + Enter`)를 사용하여 결과를 확인합니다.
# * **파일 관리**: 파일 이름을 변경하거나 구글 드라이브를 통해 저장된 파일을 불러올 수 있습니다.

# %%
print('파이썬 수업을 시작함')
# Out:
# 파이썬 수업을 시작함

# %%
print(5*100)
# Out:
# 500

# %% [markdown]
# ## 5. [실습 예제]
#
#
#
# ### 💬 문자열 출력
# 1. **기능**: `print()` 함수를 사용하여 화면에 텍스트를 출력합니다.
# 2. **로직**: 출력하고 싶은 문장을 따옴표(`' '` 또는 `" "`)로 감싸서 함수 안에 넣습니다.
# 3. **결과**: 실행 시 따옴표 내부의 글자가 화면에 나타납니다.

# %% [markdown]
# ### 🔢 연산 결과 출력
# 1. **기능**: 파이썬을 계산기처럼 사용하여 숫자 연산 결과를 출력합니다.
# 2. **로직**: `print()` 함수 안에 사칙연산(`+`, `-`, `*`, `/`) 수식을 넣습니다.
# 3. **결과**: 수식을 계산한 최종 결과값이 화면에 출력됩니다.

# %%
age = 20
print(행age)
# Out:
# age

# %%
name = '홍길동'
age = 20
print(name,'나이:',age)
# Out:
# 홍길동 나이: 20

# %%
a=b=c=7
print(a,b,c)
# Out:
# 7 7 7

# %%
a,b,c= 7,10,9
print(a,b,c)
# Out:
# 7 10 9

# %% [markdown]
# #복합대입 연산자 ( += , -=, *, /, //,% )

# %%
a,b = 2,3
a+=b
print(a)

a,b=2,3
a-=b
print(a)
# Out:
# 5
# -1

# %%
a,b = 20,2
a //=b # // ->몫
print(a)
# Out:
# 10

# %%
# 두변수 값 교환하기
a=7
b=11
a,b=b,a
print(a,b)
# Out:
# 11 7

# %%
a=3
print(a)

a+=3
print(a)

a+=3
print(a)
# Out:
# 3
# 6
# 9

# %% [markdown]
# # 자료형(int,float,str,bool)

# %%
print(type(2026))
print(type(3.14))
print(type('python'))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a= 20
b=0o34 #8진수
c=0xA1 # 16진수
d=0b1110
print(a,b,c,d)
# Out:
# 20 28 161 14

# %%
a=3.14
b=1.23e5 #e5 -> 점이 뒤로 5칸 감
c=1230000.0e-5 # e-5 -> 점이 5칸 앞으로 감
print(a,b,c)
# Out:
# 3.14 123000.0 12.3

# %%
# bool형
a= 10>20
print(a)
# Out:
# False

# %%
#string문자열 형
a = 'python'
print(a)
# Out:
# python

# %%
print('convergence'+'programming')
print(23 - 25)
print(1.23+12.3e-1)
# Out:
# convergenceprogramming
# -2
# 2.46

# %%
name= input('이름:')
age = input('나이:')
print(name,age)
# Out:
# 이름:홍길동
# 나이:20
# 홍길동 20

# %%
a=int(input('정수: '))
b=int(input('정수: '))
print(a - b)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3978722921.py in <cell line: 0>()
# ----> 1 a=int(input('정수: '))
#       2 b=int(input('정수: '))
#       3 print(a - b)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
min= float(input('분: '))
sec = min * 60
print(sec,'초')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3926344721.py in <cell line: 0>()
# ----> 1 min= float(input('분: '))
#       2 sec = min * 60
#       3 print(sec,'초')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print('반갑습니다')
score = 90
print('성적은',score,'입니다')

# %%
a=25
b=42
print(a,end=' ')
print(b)
# Out:
# 25 42

# %%
print('안녕하세요')
print()
print('Python')
# Out:
# 안녕하세요
#
# Python

# %% [markdown]
# ### f-문자열(f-string):
# 문자열 앞에 소문자f또는 대문자F를 붙이고 문자열 안의 변수를 중괄호({})로 감싸서 표현
# * 변수 값이 출력되는 형식을 지정 할 수 있음
# * 변수명 옆에 콜론을 넣고 그 다음에 형식 지정 ( 문자는 왼쪽 정렬, 숫자는 오른쪽 정렬)
# * 중괄호 안의 d는 정수를 의미, f는 부동소수점을 의미

# %%
name= '홍길동'
age =20
print(f'이름은{name}이고 나이는{age} 입니다')
print(f'{name:5}:{age:3}')
# Out:
# 이름은홍길동이고 나이는20 입니다
# 홍길동  : 20

# %%
a=25
b=1234
c=6
print(f'{a:5d}')
print(f'{b:5d}')
print(f'20{c:02d}')
# Out:
#    25
#  1234
# 2006

# %%
a=3.141592
print(f'{a},{a:.3f}')
print(f'{a:7.3f}') #.3f는 소수점 3째자리에서 반올림
# Out:
# 3.141592,3.142
#   3.142

# %%
pi=3.14159265
radius=int(input('원의 반지름: '))
area = pi*radius**2
print(f'반지름이 {radius}인 원의 넓이는 {area:.3f}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-402749759.py in <cell line: 0>()
#       1 pi=3.14159265
# ----> 2 radius=int(input('원의 반지름: '))
#       3 area = pi*radius**2
#       4 print(f'반지름이 {radius}인 원의 넓이는 {area:.3f}')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
a=int(input('정수: '))
b=int(input('정수: '))
print(f'{a} + {b} = {a+b}')
print(f'{a} - {b} = {a-b}')
print(f'{a} * {b} = {a*b}')
print(f'{a} / {b} = {a/b}')
print(f'{a} % {b} = {a%b}')
print(f'{a} // {b} = {a//b}')
# Out:
# 정수: 10
# 정수: 2
# 10 + 2 = 12
# 10 - 2 = 8
# 10 * 2 = 20
# 10 / 2 = 5.0
# 10 % 2 = 0
# 10 // 2 = 5

# %% [markdown]
# ###연산자 우선 순위
#
#
# 1.   ** 거듭제곱
# 2.   +양수 -음수
# 3.   *, / , // , %
# 4. +, -
# 5. < , <= , > , >=
# 6. ==, !== 등등 연산자 , +=,-=대입연산자
# 7. not 논리 연산자
# 8. and 논리 연산자
# 9. or 논리 연산자

# %%
#남여 비율 계산하기
male_num=int(input('남성지원자수: '))
female_num=int(input('여성지원자수: '))
total= male_num + female_num
print(f'남성비율:{male_num/total:.2f} 여성비율:{female_num / total:.2f}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3058052652.py in <cell line: 0>()
#       1 #남여 비율 계산하기
# ----> 2 male_num=int(input('남성지원자수: '))
#       3 female_num=int(input('여성지원자수: '))
#       4 total= male_num + female_num
#       5 print(f'남성비율:{male_num/total:.2f} 여성비율:{female_num / total:.2f}')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 길이 단위 변환하기
cm = int(input('센티미터 단위:'))
m = cm//100
cm= cm % 100
print(f'{m}미터 {cm}센티미터')
# Out:
# 센티미터 단위:50000
# 500미터 0센티미터

# %%
time = int(input('초 단위의 시간을 입력해주세요!'))
hour = time // 3600
minute = (time % 3600) // 60
second = (time % 3600) % 60
print(f'{hour}시간 {minute}분 {second}초 입니다.')
# Out:
# 초 단위의 시간을 입력해주세요!30000
# 8시간 20분 0초 입니다.

# %%
sec = int(input('초 단위의 시간을 입력해주세요'))
hour= sec //3600
min = sec % 3600 //60
print(f'{sec}초,{min}분,{hour}시')
# Out:
# 초 단위의 시간을 입력해주세요30000
# 30000초,20분,8시

# %%
print('아메리카노: 2000원, 라떼:3000원, 그린티:2500원')
a= int(input('아메리카노 몇잔?:'))
b = int(input('라떼 몇잔?:'))
c = int(input('그린티 몇잔?:'))
sum = a*2000+b*3000+c*2500
print(f'총 합계는{sum}원 입니다.')
# Out:
# 아메리카노: 2000원, 라떼:3000원, 그린티:2500원
# 아메리카노 몇잔?:3
# 라떼 몇잔?:3
# 그린티 몇잔?:3
# 총 합계는22500원 입니다.

# %%
americano= 2000
latte= 3000
greentea= 2500
a= int(input('아메리카노 몇잔?:'))
b = int(input('라떼 몇잔?:'))
c = int(input('그린티 몇잔?:'))
sum = a*americano + b*latte + c*greentea
print(f'총 합계는{sum}원 입니다.')
# Out:
# 아메리카노 몇잔?:2
# 라떼 몇잔?:3
# 그린티 몇잔?:1
# 총 합계는15500원 입니다.
